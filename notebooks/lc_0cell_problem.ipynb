# %%
import sys
sys.path += ["../src"]
import utils
import pandas as pd
import numpy as np
from glob import glob
import matplotlib.pyplot as plt 
import seaborn as sns
from matplotlib.pyplot import subplots as sbp 
from importlib import reload
import jl_vae
# import jl_nflows_geo_coordinates_2 as nfg
# from jl_nflows_geo_coordinates import load_nf as load_dict

from _51_abm_functions import cod_prov_abbrv_df

# %%
# transform one-hot encoding to categories
def add_cat_features(df):
    df["energy_class"] = df[[u for u in df.columns if "_energy" in u]].stack().rename("col").reset_index().query("col == 1")["level_1"]
    df["COD_CAT"] = [u[8:] for u in df[[u for u in df.columns if "COD_CAT_" in u]].stack().rename("col").reset_index().query("col == 1")["level_1"]]
    df["anno_costruzione"] = [u[17:] for u in df[[u for u in df.columns if "ANNO_COSTRUZIONE" in u]].stack().rename("col").reset_index().query("col == 1")["level_1"]]
    return df

# %%
# Load data from Jacopo's syn pops

# import dictionary with data {'hydro_risk', 'census', 'omi_og', 'cap'}
# takes ~25seconds
geo_dict = jl_vae.load_geo_data()

# check which provinces are done
glob(jl_vae.path_pop_synth + f"95sample/pop_samples/*")
# Out:
# ['/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceKR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceGO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceGR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCH.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703GR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703NO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceNA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703ME.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceKR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703KR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceME.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceGO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAQ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AQ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceEN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceIS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceNU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceNO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceGR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CH.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceIM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceNA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceOR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703GE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAQ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703IM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceFI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceOR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703NA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceUD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceNU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceBA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceGE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceTA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceGE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceIM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceSA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703OR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceME.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceAN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceMN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceNO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceBO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703RC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceLE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806pricePT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703BN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceUD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PV.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceAN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceSI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703SR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceEN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703GO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceRG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceVT.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703UD.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VB.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceLI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceRG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceVE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceIS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703CZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811pricePU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TP.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCR.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceCL.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703EN.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703NU.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTO.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703TS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703LC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703IS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceFC.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703FM.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250806priceMS.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703VA.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703PZ.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703MI.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250703AG.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceTE.csv',
#  '/data/housing/data/intermediate/jl_pop_synth/95sample/pop_samples/synthetic_pop_full_250811priceCH.csv']

# %%
import pickle

prov = "AN"

with open(f'/data/housing/data/intermediate/jl_pop_synth/isp_baselines/all_baselines_{prov}.pickle', 'rb') as f:
    all_baselines = pickle.load(f)

dummy_cols_list = ['flag_garage', 'flag_pertinenza', 'flag_air_conditioning',
    'flag_multi_floor', 'ANNO_COSTRUZIONE_1500_1965',
    'ANNO_COSTRUZIONE_1965_1985', 'ANNO_COSTRUZIONE_1985_2005',
    'ANNO_COSTRUZIONE_2005_2025', 'ANNO_COSTRUZIONE_Missing',
    'High_energy_class', 'Low_energy_class', 'Medium_energy_class',
    'Missing_energy_class', 'COD_CAT_A02', 'COD_CAT_A03',
    'COD_CAT_A_01_07_08', 'COD_CAT_A_04_05', 'floor_0.0', 'floor_1.0',
    'floor_2.0', 'floor_3.0', 'floor_Missing', 'floor_plus_4',
    'flag_air_conditioning_Missing', 'flag_multi_floor_Missing']

coord_cols_list = ['x','y']
cont_cols_list = ['log_mq','log_price']

# %%
# function returning the dataframes containing populations with continuous columns binned
def ConvertBool2number(df):
    bool_cols = df.select_dtypes(include=bool).columns
    df[bool_cols] = df[bool_cols].astype(float)
    df = df.reset_index(drop=True)
    return df

def BinnedContColumns(df_syn,df_real,vars):
    df = df_syn.copy()
    for var in vars:
        bins_values = pd.qcut(df_real[var], q = 5, labels = False, duplicates = "drop", retbins = True)[1]
        # in the following 2 rows I make that mq and prices lower than the real ones go inside the same bins
        bins_values[0] = -np.inf
        bins_values[-1] = np.inf
        df[var+'_bin'] = pd.cut(x = df_syn[var],bins = bins_values, labels=[0,1,2,3,4],include_lowest=True)
        
        df.drop(columns = [var], inplace = True)

    return df

def Transform_bins(df, vars):
    df1 = df.copy()
    for var in vars:
        df1[var + "_bin"] =  pd.qcut(df1[var], q = 5, labels = [0,1,2,3,4], duplicates = "drop").astype(int)
        df1.drop(columns = [var], inplace = True)
    return df1

def DataPreparation(data,keys,cont_cols,geo_dict):
    data_prep = dict() # output dictionary
    for key in keys: # loop across keys
        df = data[key].copy() # selecting the data

        # convert bool to integers
        df = ConvertBool2number(df)

        # binning the continuous columns
        if 'real' in key:
            df = Transform_bins(df, cont_cols)
        else:
            df = BinnedContColumns(df,data['df_real'],cont_cols)

        # add CAP and other stuff
        df = utils.spatial_matching_ABM(df, geo_dict["hydro_risk"], geo_dict["census"], 
                                        geo_dict["omi_og"], geo_dict["cap"])
        
        data_prep[key] = df
    
    return data_prep

# %%
keys_list = ['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation']
keys_list95 = ['df_real95', 'df_nfvae95', 'df_ablation95', 'df_ipf95', 'df_copula_nf95', 'df_copula_ablation95']

# %%
data = DataPreparation(data = all_baselines,keys=keys_list,
                    cont_cols=cont_cols_list,geo_dict=geo_dict)

# %%
data['df_real'].columns
# Out:
# Index(['flag_garage', 'flag_pertinenza', 'flag_air_conditioning',
#        'flag_multi_floor', 'GEO_LATITUDINE_BENE_ROUNDED',
#        'GEO_LONGITUDINE_BENE_ROUNDED', 'ANNO_COSTRUZIONE_1500_1965',
#        'ANNO_COSTRUZIONE_1965_1985', 'ANNO_COSTRUZIONE_1985_2005',
#        'ANNO_COSTRUZIONE_2005_2025', 'ANNO_COSTRUZIONE_Missing',
#        'High_energy_class', 'Low_energy_class', 'Medium_energy_class',
#        'Missing_energy_class', 'COD_CAT_A02', 'COD_CAT_A03',
#        'COD_CAT_A_01_07_08', 'COD_CAT_A_04_05', 'floor_0.0', 'floor_1.0',
#        'floor_2.0', 'floor_3.0', 'floor_Missing', 'floor_plus_4',
#        'flag_air_conditioning_Missing', 'flag_multi_floor_Missing',
#        'log_mq_bin', 'log_price_bin', 'COD_CONTRATTO', 'SEZ2011', 'PRO_COM',
#        'flag_geo_valid', 'CAP', 'OMI_id', 'OMI_categ', 'scenario',
#        'scenario_LowRisk', 'scenario_MediumRisk', 'scenario_NoRisk',
#        'scenario_HighRisk', 'scenario_Risk', 'flag_italy', 'COD_PROV',
#        'COD_REG', 'regione_nome', 'prov_nome', 'prov_abbrv',
#        'year_erogaz_prov'],
#       dtype='object')

# %%
for key in data.keys():
    print(key,' Num homes with flag_geo_flaid = 1: ', data[key].flag_geo_valid.sum())
# Out:
# df_real  Num homes with flag_geo_flaid = 1:  4252
# df_nfvae  Num homes with flag_geo_flaid = 1:  4252
# df_ablation  Num homes with flag_geo_flaid = 1:  4252
# df_ipf  Num homes with flag_geo_flaid = 1:  4252
# df_copula_nf  Num homes with flag_geo_flaid = 1:  4252
# df_copula_ablation  Num homes with flag_geo_flaid = 1:  4252

# %%
# drop useless columns
col2drop = ['COD_CONTRATTO', 'SEZ2011', 'PRO_COM',
       'flag_geo_valid', 'OMI_id', 'OMI_categ', 'scenario',
       'scenario_LowRisk', 'scenario_MediumRisk', 'scenario_NoRisk',
       'scenario_HighRisk', 'scenario_Risk', 'flag_italy', 'COD_PROV',
       'COD_REG', 'regione_nome', 'prov_nome', 'prov_abbrv',
       'year_erogaz_prov']

for key in data.keys():
    data[key] = data[key].drop(columns=col2drop)

# %%
data['df_real'].columns
# Out:
# Index(['flag_garage', 'flag_pertinenza', 'flag_air_conditioning',
#        'flag_multi_floor', 'GEO_LATITUDINE_BENE_ROUNDED',
#        'GEO_LONGITUDINE_BENE_ROUNDED', 'ANNO_COSTRUZIONE_1500_1965',
#        'ANNO_COSTRUZIONE_1965_1985', 'ANNO_COSTRUZIONE_1985_2005',
#        'ANNO_COSTRUZIONE_2005_2025', 'ANNO_COSTRUZIONE_Missing',
#        'High_energy_class', 'Low_energy_class', 'Medium_energy_class',
#        'Missing_energy_class', 'COD_CAT_A02', 'COD_CAT_A03',
#        'COD_CAT_A_01_07_08', 'COD_CAT_A_04_05', 'floor_0.0', 'floor_1.0',
#        'floor_2.0', 'floor_3.0', 'floor_Missing', 'floor_plus_4',
#        'flag_air_conditioning_Missing', 'flag_multi_floor_Missing',
#        'log_mq_bin', 'log_price_bin', 'CAP'],
#       dtype='object')

# %%
# list of all CAP codes in the selected province
cap_list = []
for key in data.keys():
    cap_list.append(data[key].CAP.unique())

cap = np.unique(np.concatenate(cap_list))
cap
# Out:
# array(['60010', '60011', '60012', '60013', '60015', '60018', '60019',
#        '60020', '60021', '60022', '60024', '60025', '60026', '60027',
#        '60030', '60031', '60033', '60034', '60035', '60036', '60037',
#        '60038', '60039', '60040', '60041', '60043', '60044', '60048',
#        '60121', '60122', '60123', '60124', '60125', '60126', '60127',
#        '60128', '60129', '60131'], dtype=object)

# %%
# passare da dummy variables to categorical columns
import pandas as pd

def dummies_to_category(df, cols, new_col, mapping=None, drop=True):
    """
    Converte un insieme di variabili dummy in una colonna categorica.

    Parametri
    ----------
    df : pd.DataFrame
        Il dataframe di input.
    cols : list
        Lista delle colonne dummy da combinare.
    new_col : str
        Nome della nuova colonna categorica.
    mapping : dict, opzionale
        Dizionario per rinominare le categorie {dummy_col: categoria}.
    drop : bool, default True
        Se True elimina le colonne dummy originali.

    Ritorna
    -------
    pd.DataFrame
        DataFrame con la nuova colonna categorica.
    """
    df = df.copy()
    
    # trova la colonna con il valore 1
    df[new_col] = df[cols].idxmax(axis=1)
    
    # se c'è un mapping, rinomina le categorie
    if mapping is not None:
        df[new_col] = df[new_col].map(mapping)
    
    # eventualmente elimina le colonne dummy
    if drop:
        df.drop(columns=cols, inplace=True)
    
    return df

# %%
energy_cols = ['High_energy_class', 'Low_energy_class', 'Medium_energy_class','Missing_energy_class']
floor_cols = ['floor_0.0', 'floor_1.0', 'floor_2.0', 'floor_3.0', 'floor_Missing', 'floor_plus_4']
cod_cat_cols = ['COD_CAT_A02', 'COD_CAT_A03', 'COD_CAT_A_01_07_08', 'COD_CAT_A_04_05']
anno_costr_cols = ['ANNO_COSTRUZIONE_1500_1965','ANNO_COSTRUZIONE_1965_1985', 'ANNO_COSTRUZIONE_1985_2005',
       'ANNO_COSTRUZIONE_2005_2025', 'ANNO_COSTRUZIONE_Missing']
ac_cols = ['flag_air_conditioning','flag_air_conditioning_Missing']
multi_floor_cols = ['flag_multi_floor','flag_multi_floor_Missing']

# %%
data_rev = dict()
for key in data.keys():
    df=data[key].copy()
    df = dummies_to_category(df,energy_cols,'energy_class')
    df = dummies_to_category(df,floor_cols,'floor')
    df = dummies_to_category(df,cod_cat_cols,'cod_cat')
    df = dummies_to_category(df,anno_costr_cols,'costr_year')
    df = dummies_to_category(df,ac_cols,'air_conditioning')
    df = dummies_to_category(df,multi_floor_cols,'multi_floor')

    df = df.drop(columns=['GEO_LATITUDINE_BENE_ROUNDED','GEO_LONGITUDINE_BENE_ROUNDED'])

    data_rev[key] = df
    del df

# %%
data_rev['df_real']
# Out:
#       flag_garage  flag_pertinenza  log_mq_bin  log_price_bin    CAP  \
# 0             1.0              0.0           1              2  60123
# 1             0.0              0.0           0              0  60025
# 2             0.0              0.0           4              1  60025
# 3             1.0              0.0           2              2  60012
# 4             0.0              0.0           1              1  60124
# ...           ...              ...         ...            ...    ...
# 4247          1.0              0.0           2              3  60020
# 4248          1.0              0.0           4              3  60020
# 4249          1.0              0.0           3              4  60020
# 4250          0.0              0.0           3              1  60020
# 4251          1.0              0.0           0              4  60019
#
#               energy_class          floor      cod_cat  \
# 0     Missing_energy_class  floor_Missing  COD_CAT_A02
# 1     Missing_energy_class  floor_Missing  COD_CAT_A02
# 2     Missing_energy_class  floor_Missing  COD_CAT_A03
# 3         Low_energy_class  floor_Missing  COD_CAT_A02
# 4     Missing_energy_class  floor_Missing  COD_CAT_A02
# ...                    ...            ...          ...
# 4247   Medium_energy_class  floor_Missing  COD_CAT_A02
# 4248   Medium_energy_class  floor_Missing  COD_CAT_A02
# 4249     High_energy_class  floor_Missing  COD_CAT_A02
# 4250      Low_energy_class  floor_Missing  COD_CAT_A02
# 4251     High_energy_class  floor_Missing  COD_CAT_A02
#
#                       costr_year               air_conditioning  \
# 0     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# 1     ANNO_COSTRUZIONE_1965_1985  flag_air_conditioning_Missing
# 2     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# 3     ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# ...                          ...                            ...
# 4247  ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4248  ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4249  ANNO_COSTRUZIONE_2005_2025  flag_air_conditioning_Missing
# 4250  ANNO_COSTRUZIONE_1500_1965          flag_air_conditioning
# 4251  ANNO_COSTRUZIONE_2005_2025          flag_air_conditioning
#
#                    multi_floor
# 0     flag_multi_floor_Missing
# 1     flag_multi_floor_Missing
# 2     flag_multi_floor_Missing
# 3     flag_multi_floor_Missing
# 4     flag_multi_floor_Missing
# ...                        ...
# 4247  flag_multi_floor_Missing
# 4248  flag_multi_floor_Missing
# 4249  flag_multi_floor_Missing
# 4250  flag_multi_floor_Missing
# 4251  flag_multi_floor_Missing
#
# [4252 rows x 11 columns]

# %% [markdown]
# ## Conto il numero di classi uniche per CAP
# all'interno di questa sezione, conto (per ogni colonna) il numero di classi uniche per ogni CAP

# %%
count_cap = dict()
for key in data_rev.keys():
    df = data_rev[key].copy()
    res = pd.DataFrame(columns=['flag_garage','flag_pertinenza','log_mq_bin','log_price_bin',
                                'energy_class','floor','cod_cat','costr_year','air_conditioning','multi_floor'])
    for cap in df.CAP.unique():
        for c in res.columns:
            res.loc[cap,c] = len(df.loc[df.CAP == cap, c].unique())

    count_cap[key] = res

# %%
count_cap['df_real'].floor.value_counts()
# Out:
# floor
# 2    13
# 1     7
# 4     7
# 5     6
# 3     4
# 6     1
# Name: count, dtype: int64

# %%
count_cap['df_nfvae'].floor.value_counts()
# Out:
# floor
# 1    38
# Name: count, dtype: int64

# %%
count_cap.keys()
# Out:
# dict_keys(['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation'])

# %%
for key in count_cap.keys():
    count_cap[key] = count_cap[key].sort_index()

# %%
count_cap['df_real']
# Out:
#       flag_garage flag_pertinenza log_mq_bin log_price_bin energy_class floor  \
# 60010           2               2          5             5            4     2
# 60011           2               2          5             5            3     1
# 60012           2               2          5             5            4     2
# 60013           2               2          5             5            4     2
# 60015           2               2          5             5            4     4
# 60018           2               2          5             5            4     2
# 60019           2               2          5             5            4     5
# 60020           2               2          5             5            4     3
# 60021           2               2          5             5            4     1
# 60022           2               2          5             5            4     2
# 60024           2               2          3             5            4     2
# 60025           2               2          5             5            4     1
# 60026           2               2          5             5            4     3
# 60027           2               2          5             5            4     5
# 60030           2               2          5             5            4     4
# 60031           2               1          4             4            4     2
# 60033           2               2          5             5            4     5
# 60034           2               2          5             5            4     2
# 60035           2               2          5             5            4     6
# 60036           2               2          4             4            3     1
# 60037           2               2          5             5            4     4
# 60038           2               1          2             3            2     1
# 60039           2               2          4             5            4     2
# 60040           2               2          3             5            3     1
# 60041           2               2          5             5            4     2
# 60043           2               2          5             5            4     1
# 60044           2               2          5             5            4     2
# 60048           2               2          4             4            3     2
# 60121           2               2          5             5            3     5
# 60122           2               2          5             5            4     4
# 60123           2               2          5             5            4     5
# 60124           2               2          5             5            4     4
# 60125           2               2          5             5            4     3
# 60126           2               2          5             5            4     5
# 60127           2               2          5             5            4     4
# 60128           2               2          5             5            4     3
# 60129           2               2          5             5            4     2
# 60131           2               2          5             5            4     4
#
#       cod_cat costr_year air_conditioning multi_floor
# 60010       4          4                2           2
# 60011       3          4                2           1
# 60012       4          4                2           2
# 60013       3          4                2           2
# 60015       4          4                2           2
# 60018       4          4                2           2
# 60019       4          4                2           2
# 60020       4          4                2           2
# 60021       4          5                2           1
# 60022       4          4                2           2
# 60024       3          4                2           2
# 60025       4          4                2           1
# 60026       3          4                2           2
# 60027       4          5                2           2
# 60030       4          4                2           2
# 60031       3          4                2           2
# 60033       3          5                2           2
# 60034       3          4                2           2
# 60035       4          4                2           2
# 60036       2          2                2           1
# 60037       4          4                2           2
# 60038       2          2                1           1
# 60039       4          4                2           2
# 60040       4          4                2           1
# 60041       4          4                2           2
# 60043       3          4                2           1
# 60044       4          4                2           2
# 60048       2          3                2           2
# 60121       3          4                2           2
# 60122       3          4                2           2
# 60123       4          5                2           2
# 60124       4          5                2           2
# 60125       3          4                2           2
# 60126       4          4                2           2
# 60127       4          4                2           2
# 60128       3          4                2           2
# 60129       3          4                2           2
# 60131       4          4                2           2

# %%
count_cap['df_nfvae']
# Out:
#       flag_garage flag_pertinenza log_mq_bin log_price_bin energy_class floor  \
# 60010           2               2          5             5            4     1
# 60011           1               2          1             2            2     1
# 60012           2               2          5             5            4     1
# 60013           2               2          4             3            3     1
# 60015           2               2          5             5            4     1
# 60018           2               2          5             5            4     1
# 60019           2               2          5             5            4     1
# 60020           2               2          5             5            4     1
# 60021           2               2          5             5            3     1
# 60022           2               2          5             5            3     1
# 60024           2               2          5             4            3     1
# 60025           2               2          5             5            3     1
# 60026           2               2          5             5            3     1
# 60027           2               2          5             5            4     1
# 60030           2               2          5             5            4     1
# 60031           2               2          2             4            2     1
# 60033           2               1          5             5            4     1
# 60034           2               2          5             5            4     1
# 60035           2               2          5             5            4     1
# 60036           1               2          2             3            2     1
# 60037           2               2          5             5            3     1
# 60038           2               1          1             1            2     1
# 60039           2               2          5             5            3     1
# 60040           2               2          4             4            2     1
# 60041           2               2          3             5            3     1
# 60043           2               2          5             5            3     1
# 60044           2               2          5             5            4     1
# 60048           2               2          4             5            3     1
# 60121           2               2          5             5            3     1
# 60122           2               2          5             5            4     1
# 60123           2               2          5             5            3     1
# 60124           2               2          5             5            4     1
# 60125           2               2          5             5            4     1
# 60126           2               2          5             5            4     1
# 60127           2               2          5             5            4     1
# 60128           2               2          5             5            4     1
# 60129           2               2          5             5            4     1
# 60131           2               2          5             5            4     1
#
#       cod_cat costr_year air_conditioning multi_floor
# 60010       3          4                2           2
# 60011       1          3                1           1
# 60012       2          4                2           2
# 60013       2          4                2           1
# 60015       4          4                2           2
# 60018       3          4                2           2
# 60019       4          4                2           2
# 60020       4          4                2           2
# 60021       4          4                2           2
# 60022       3          4                2           2
# 60024       2          3                2           2
# 60025       4          4                2           2
# 60026       3          4                2           1
# 60027       4          4                2           2
# 60030       4          4                2           2
# 60031       2          4                2           1
# 60033       2          4                2           2
# 60034       4          3                2           2
# 60035       4          4                2           2
# 60036       2          3                1           1
# 60037       3          4                2           2
# 60038       2          2                2           1
# 60039       2          4                2           2
# 60040       3          4                2           1
# 60041       3          4                2           1
# 60043       3          4                2           2
# 60044       4          4                2           2
# 60048       2          4                2           1
# 60121       3          4                2           2
# 60122       3          4                2           2
# 60123       3          4                2           1
# 60124       3          4                2           1
# 60125       4          4                2           2
# 60126       4          4                2           2
# 60127       4          4                2           2
# 60128       4          4                2           2
# 60129       4          4                2           2
# 60131       4          4                2           2

# %% [markdown]
# Non sembra andare molto bene, infatti il nostro modo (nf+vae) sembra preferirie troppo spesso le classi maggioritario (es floor)

# %% [markdown]
# ## Conta case uniche per CAP

# %%
data_rev.keys()
# Out:
# dict_keys(['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation'])

# %%
count_cap1 = pd.DataFrame(columns=['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation'])

for cap in data_rev['df_real'].CAP.unique():
    for pop in count_cap1.columns:
        # number of houses in the CAP for the given syn pop
        df = data_rev[pop].copy()
        df_cap = df.loc[df.CAP == cap,:]
        N_homes_cap = 1 #len(df_cap)

        # number of unique homes in the CAP
        unique_homes = df_cap.drop_duplicates()
        N_unique_homes = len(unique_homes)

        if N_homes_cap != 0:
            count_cap1.loc[cap,pop] = N_unique_homes/N_homes_cap
        else:
            count_cap1.loc[cap,pop] = np.nan

# %%
count_cap1 = count_cap1.sort_index()
count_cap1
# Out:
#       df_real df_nfvae df_ablation df_ipf df_copula_nf df_copula_ablation
# 60010    64.0     64.0        17.0   41.0         61.0              219.0
# 60011    15.0      3.0         4.0    7.0         27.0              159.0
# 60012    66.0     71.0       142.0   44.0         69.0               48.0
# 60013    28.0     19.0        17.0   19.0         33.0               89.0
# 60015   187.0    105.0       110.0  123.0        244.0              101.0
# 60018    88.0     59.0        77.0   51.0         89.0               70.0
# 60019   320.0    206.0       195.0  232.0        327.0              195.0
# 60020   164.0    106.0       135.0  105.0        191.0              305.0
# 60021    59.0     43.0        39.0   41.0         54.0               81.0
# 60022   149.0     83.0        40.0   92.0        167.0              107.0
# 60024    15.0     11.0        34.0    8.0          7.0              130.0
# 60025   102.0     78.0         9.0   74.0        105.0               38.0
# 60026    78.0     56.0        44.0   51.0         80.0               45.0
# 60027   221.0    117.0        76.0  159.0        256.0              278.0
# 60030   138.0    100.0       110.0   93.0        162.0              424.0
# 60031    15.0     23.0         2.0    9.0         21.0               25.0
# 60033   106.0     48.0        29.0   64.0        126.0               66.0
# 60034    25.0     27.0        38.0   13.0         20.0               51.0
# 60035   228.0    131.0       109.0  153.0        267.0              252.0
# 60036     8.0      5.0         4.0    5.0          4.0               52.0
# 60037    56.0     27.0        23.0   35.0         49.0               78.0
# 60038     5.0      2.0        26.0    2.0         11.0               21.0
# 60039    18.0     14.0        29.0   14.0         25.0               50.0
# 60040    12.0     15.0        12.0    7.0         10.0               43.0
# 60041    36.0     39.0         3.0   23.0         56.0               33.0
# 60043    27.0     22.0        23.0   16.0         26.0                4.0
# 60044   163.0    118.0       160.0  111.0        202.0               40.0
# 60048    12.0     21.0        17.0    6.0         16.0               42.0
# 60121    49.0     44.0         0.0   31.0         77.0                8.0
# 60122    64.0     62.0         0.0   38.0        134.0               10.0
# 60123    98.0     56.0         0.0   66.0         74.0                4.0
# 60124    69.0     50.0         0.0   42.0         49.0                3.0
# 60125    95.0     47.0         0.0   76.0         86.0               12.0
# 60126   143.0     80.0        41.0   99.0        186.0               86.0
# 60127   104.0     69.0         0.0   74.0        102.0               11.0
# 60128   111.0     61.0         0.0   79.0        104.0                9.0
# 60129    47.0     60.0         7.0   33.0         65.0              110.0
# 60131   172.0     90.0       118.0  127.0        199.0              326.0

# %%
data_rev.keys()
# Out:
# dict_keys(['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation'])

# %%
data_rev['df_real']
# Out:
#       flag_garage  flag_pertinenza  log_mq_bin  log_price_bin    CAP  \
# 0             1.0              0.0           1              2  60123
# 1             0.0              0.0           0              0  60025
# 2             0.0              0.0           4              1  60025
# 3             1.0              0.0           2              2  60012
# 4             0.0              0.0           1              1  60124
# ...           ...              ...         ...            ...    ...
# 4247          1.0              0.0           2              3  60020
# 4248          1.0              0.0           4              3  60020
# 4249          1.0              0.0           3              4  60020
# 4250          0.0              0.0           3              1  60020
# 4251          1.0              0.0           0              4  60019
#
#               energy_class          floor      cod_cat  \
# 0     Missing_energy_class  floor_Missing  COD_CAT_A02
# 1     Missing_energy_class  floor_Missing  COD_CAT_A02
# 2     Missing_energy_class  floor_Missing  COD_CAT_A03
# 3         Low_energy_class  floor_Missing  COD_CAT_A02
# 4     Missing_energy_class  floor_Missing  COD_CAT_A02
# ...                    ...            ...          ...
# 4247   Medium_energy_class  floor_Missing  COD_CAT_A02
# 4248   Medium_energy_class  floor_Missing  COD_CAT_A02
# 4249     High_energy_class  floor_Missing  COD_CAT_A02
# 4250      Low_energy_class  floor_Missing  COD_CAT_A02
# 4251     High_energy_class  floor_Missing  COD_CAT_A02
#
#                       costr_year               air_conditioning  \
# 0     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# 1     ANNO_COSTRUZIONE_1965_1985  flag_air_conditioning_Missing
# 2     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# 3     ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4     ANNO_COSTRUZIONE_1500_1965  flag_air_conditioning_Missing
# ...                          ...                            ...
# 4247  ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4248  ANNO_COSTRUZIONE_1985_2005  flag_air_conditioning_Missing
# 4249  ANNO_COSTRUZIONE_2005_2025  flag_air_conditioning_Missing
# 4250  ANNO_COSTRUZIONE_1500_1965          flag_air_conditioning
# 4251  ANNO_COSTRUZIONE_2005_2025          flag_air_conditioning
#
#                    multi_floor
# 0     flag_multi_floor_Missing
# 1     flag_multi_floor_Missing
# 2     flag_multi_floor_Missing
# 3     flag_multi_floor_Missing
# 4     flag_multi_floor_Missing
# ...                        ...
# 4247  flag_multi_floor_Missing
# 4248  flag_multi_floor_Missing
# 4249  flag_multi_floor_Missing
# 4250  flag_multi_floor_Missing
# 4251  flag_multi_floor_Missing
#
# [4252 rows x 11 columns]

# %%
data_rev['df_ipf'].loc[0,:].isin(data_rev['df_real'])
# Out:
# flag_garage         False
# flag_pertinenza     False
# log_mq_bin          False
# log_price_bin       False
# CAP                 False
# energy_class        False
# floor               False
# cod_cat             False
# costr_year          False
# air_conditioning    False
# multi_floor         False
# Name: 0, dtype: bool

# %% [markdown]
# Osservazioni nei dataframe binnati che esistono nei dati sintetici ma non ci sono nei dati reali

# %%
from sklearn.metrics import pairwise_distances
import gower

def TableIMS(data, control_data, metric='euclidean'):
    res = pd.DataFrame(columns=['equal_homes','different_homes'])
    for i in control_data:
        # Distance matrix
        if(metric=='euclidean'):
            train_dists = pairwise_distances(data[i].values, data['df_real'].values, metric='euclidean') 
        elif(metric=='norm1'):
            train_dists = pairwise_distances(data[i].values, data['df_real'].values, metric='minkowski', p=1) 
        elif(metric == 'gower'):
            train_dists = gower.gower_matrix(data[i],data['df_real'] )
        
        # take the minimum distances
        min_dists_train = train_dists.min(axis=1)

        res.loc[i,:] = [np.sum(min_dists_train==0), np.sum(min_dists_train!=0)]

    return res

# %%
data_rev.keys()
# Out:
# dict_keys(['df_real', 'df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation'])

# %%
control = ['df_nfvae', 'df_ablation', 'df_ipf', 'df_copula_nf', 'df_copula_ablation']
res = TableIMS(data_rev,control,metric='gower')

# %%
res
# Out:
#                    equal_homes different_homes
# df_nfvae                  1002            3250
# df_ablation                823            3429
# df_ipf                    1820            2432
# df_copula_nf               516            3736
# df_copula_ablation         411            3841

# %%
res['sum'] = res['equal_homes'] + res['different_homes']
res
# Out:
#                    equal_homes different_homes   sum
# df_nfvae                  1002            3250  4252
# df_ablation                823            3429  4252
# df_ipf                    1820            2432  4252
# df_copula_nf               516            3736  4252
# df_copula_ablation         411            3841  4252

# %%
len(data_rev['df_real'])
# Out:
# 4252

# %%
1820/4252
# Out:
# 0.4280338664158043
